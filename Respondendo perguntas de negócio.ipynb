# %%
import pandas as pd
import inflection

df_raw = pd.read_csv("dataset/zomato.csv")
df_raw.head()
# Out:
#    Restaurant ID             Restaurant Name  Country Code            City  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 1        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 2        6314542                   Blackbird           162     Makati City
# 3        6301293                    Banapple           162     Makati City
# 4        6315689                    Bad Bird           162     Makati City
#
#                                              Address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4  Hole In The Wall, Floor 4, Century City Mall, ...
#
#                                             Locality  \
# 0                                   BF International
# 1                                   BF International
# ...

# %% [markdown]
# # Limpeza do dataframe

# %%
# Fazendo uma cópia do dataset
df = df_raw.copy()

# Removendo espaços dos nomes das colunas
df.columns = df.columns.str.replace(' ', '_')

# Removendo colunas que não serão utilizadas
df.drop(["Switch_to_order_menu"], axis=1, inplace=True)

#Removendo valores "NaN" de todas as colunas
df.dropna(inplace=True)

df.drop(df[(df["Cuisines"] == "Drinks Only")].index)

df.drop(df[(df["Cuisines"] == "Mineira")].index)
# Out:
#       Restaurant_ID                    Restaurant_Name  Country_Code  \
# 0           6310675         Mama Lou's Italian Kitchen           162
# 1           6310675         Mama Lou's Italian Kitchen           162
# 2           6314542                          Blackbird           162
# 3           6301293                           Banapple           162
# 4           6315689                           Bad Bird           162
# ...             ...                                ...           ...
# 7522        5912546                             Eataly           208
# 7523        5913006  Tarihi Çınaraltı Aile Çay Bahçesi           208
# 7524        5923535             Boon Cafe & Restaurant           208
# 7525        5914190                   Kanaat Lokantası           208
# 7526        5913508                            Katibim           208
#
#                 City                                            Address  \
# ...

# %% [markdown]
# ## Renomear as colunas do DataFrame

# %%
def rename_columns(dataframe):
    df = dataframe.copy()
    title = lambda x: inflection.titleize(x)
    snakecase = lambda x: inflection.underscore(x)
    spaces = lambda x: x.replace(" ", "")
    cols_old = list(df.columns)
    cols_old = list(map(title, cols_old))
    cols_old = list(map(spaces, cols_old))
    cols_new = list(map(snakecase, cols_old))
    df.columns = cols_new
    return df

df = rename_columns(df)

# %% [markdown]
# ## Categorizando todos os restaurantes somente por um topo de culinária

# %%
df["cuisines"] = df["cuisines"].apply(lambda x: str(x).split(",")[0] if pd.notnull(x) else x)

# %%
#Remover valores "NaN" da coluna "Cuisines"
df = df[df["cuisines"].notnull()]

# %% [markdown]
# # Preenchimento do nome dos países

# %%
COUNTRIES = {
    1: "India",
    14: "Australia",
    30: "Brazil",
    37: "Canada",
    94: "Indonesia",
    148: "New Zealand",
    162: "Phillipines",
    166: "Qatar",
    184: "Singapore",
    189: "South Africa",
    191: "Sri Lanka",
    208: "Turkey",
    214: "United Arab Emirates",
    215: "United Kingdom",
    216: "United States"
}

def country_name(country_id):
    return COUNTRIES[country_id]

# %% [markdown]
# # Criando a coluna country na posição 2 do dataframe

# %%
#criando coluna Country na posição 2
df.insert(loc=2, column="country", value=df["country_code"].apply(country_name))

# %% [markdown]
# # Removendo a coluna country_code

# %%
#Removendo coluna Country_Code
df.drop(["country_code"], axis=1, inplace=True)

# %% [markdown]
# # Criação do tipo de categoria de comida

# %%
def create_price_type(price_range):
    if price_range == "1":
        return "cheap"
    elif price_range == "2":
        return "normal"
    elif price_range == "3":
        return "expensive"
    else:
        return "gourmet"

# %% [markdown]
# ## Criando coluna price_type ao lado da coluna cuisines

# %%
df.insert(loc=10, column="price_type", value=df["price_range"].apply(create_price_type))

# %% [markdown]
# ## Removendo a coluna price_range

# %%
#removendo coluna Price_Range
df.drop(["price_range"], axis=1, inplace=True)

# %% [markdown]
# # Criação do nome das cores

# %%
COLORS = {
    "3F7E00": "dark_green",
    "5BA829": "green",
    "9ACD32": "lightgreen",
    "CDD614": "orange",
    "FFBA00": "red",
    "CBCBC8": "darkred",
    "FF7800": "lightred",
}

def color_name(color_code):
    return COLORS[color_code]

# %% [markdown]
# ## Criando a coluna color_name na posição 18

# %%
df.insert(loc=18, column="color_name", value=df["rating_color"].apply(color_name))

# %% [markdown]
# # Respondendo as perguntas de negócio

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    restaurant             restaurant_name      country            city  \
# 0     6310675  Mama Lou's Italian Kitchen  Phillipines  Las Piñas City
# 1     6310675  Mama Lou's Italian Kitchen  Phillipines  Las Piñas City
# 2     6314542                   Blackbird  Phillipines     Makati City
# 3     6301293                    Banapple  Phillipines     Makati City
# 4     6315689                    Bad Bird  Phillipines     Makati City
#
#                                              address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4  Hole In The Wall, Floor 4, Century City Mall, ...
#
#                                             locality  \
# 0                                   BF International
# 1                                   BF International
# ...

# %%
df1.dtypes
# Out:
# restaurant                int64
# restaurant_name          object
# country                  object
# city                     object
# address                  object
# locality                 object
# locality_verbose         object
# longitude               float64
# latitude                float64
# cuisines                 object
# price_type               object
# average_cost_for_two      int64
# currency                 object
# has_table_booking         int64
# has_online_delivery       int64
# is_delivering_now         int64
# aggregate_rating        float64
# rating_color             object
# color_name               object
# rating_text              object
# votes                     int64
# dtype: object

# %% [markdown]
# # Geral

# %% [markdown]
# ## 1. Quantos restaurantes únicos estão registrados?

# %%
df1["restaurant"].nunique()
# Out:
# 6929

# %% [markdown]
# ## 2. Quantos países únicos estão registrados?

# %%
df1["country"].nunique()
# Out:
# 15

# %% [markdown]
# ## 3. Quantas cidades únicas estão registradas?

# %%
df1["city"].nunique()
# Out:
# 125

# %% [markdown]
# ## 4. Qual o total de avaliações feitas?

# %%
df1["votes"].sum()
# Out:
# 4194533

# %% [markdown]
# ## 5. Qual o total de tipos de culinárias registradas?

# %%
df1["cuisines"].nunique()
# Out:
# 165

# %% [markdown]
# # País

# %% [markdown]
# ## 1. Qual o nome do país que possui mais cidades registradas?

# %%
# Nome do país que possui mais cidades registradas
df1.groupby("country")["city"].nunique().sort_values(ascending=False).head(1)
# Out:
# country
# India    49
# Name: city, dtype: int64

# %% [markdown]
# ## 2. Qual o nome do país que possui mais restaurantes registrados?

# %%
df1.groupby("country")["restaurant"].nunique().sort_values(ascending=False).head(1)
# Out:
# country
# India    3111
# Name: restaurant, dtype: int64

# %% [markdown]
# ## 3. Qual o nome do país que possui mais restaurantes com o nível de preço igual a 4 registrados?

# %%
df1[df1["price_range"] == 4]["country"].value_counts().idxmax()
# Out:
# 'United States'

# %% [markdown]
# ## 4. Qual o nome do país que possui a maior quantidade de tipos de culinárias distintos?

# %%
df1.groupby("country")["cuisines"].nunique().idxmax()
# Out:
# 'India'

# %% [markdown]
# ## 5. Qual o nome do país que possui a maior quantidade de avaliações feitas?

# %%
df1.groupby("country")["votes"].sum().sort_values(ascending=False).reset_index().head(1)
# Out:
#   country    votes
# 0   India  2800164

# %% [markdown]
# ## 6. Qual o nome do país que possui a maior quantidade de restaurantes que fazem entrega?

# %%
df1.groupby("country")["is_delivering_now"].nunique().sort_values(ascending=False).reset_index().head(1)
# Out:
#   country  is_delivering_now
# 0   India                  2

# %% [markdown]
# ## 7. Qual o nome do país que possui a maior quantidade de restaurantes que aceitam reservas?

# %%
df1.groupby("country")["has_table_booking"].nunique().sort_values(ascending=False).reset_index().head(1)
# Out:
#      country  has_table_booking
# 0  Australia                  2

# %% [markdown]
# ## 8. Qual o nome do país que possui, na média, a maior quantidade de avaliações registrada?

# %%
df1.groupby("country")["votes"].mean().idxmax()
# Out:
# 'Indonesia'

# %% [markdown]
# ## 9. Qual o nome do país que possui, na média, a maior nota média registrada?

# %%
df1.groupby("country")["aggregate_rating"].mean().idxmax()
# Out:
# 'Indonesia'

# %% [markdown]
# ## 10. Qual o nome do país que possui, na média, a menor nota média registrada?

# %%
df1.groupby("country")["aggregate_rating"].mean().idxmin()
# Out:
# 'Brazil'

# %% [markdown]
# ## 11. Qual a média de preço de um prato para dois por país?

# %%
df1.groupby("country")["average_cost_for_two"].mean().sort_values(ascending=False).astype(float).round(2).reset_index()
# Out:
#                  country  average_cost_for_two
# 0              Indonesia             303000.00
# 1              Australia             138959.78
# 2              Sri Lanka               2579.38
# 3            Phillipines               1227.82
# 4                  India                704.40
# 5           South Africa                339.23
# 6                  Qatar                174.00
# 7   United Arab Emirates                153.72
# 8              Singapore                141.44
# 9                 Brazil                138.81
# 10                Turkey                128.58
# 11           New Zealand                 62.15
# 12         United States                 55.03
# 13        United Kingdom                 43.51
# 14                Canada                 41.86

# %% [markdown]
# # Cidade

# %% [markdown]
# ## 1. Qual o nome da cidade que possui mais restaurantes registrados?

# %%
df1.groupby("city")["restaurant"].nunique().idxmax()
# Out:
# 'Abu Dhabi'

# %% [markdown]
# ## 2. Qual o nome da cidade que possui mais restaurantes com nota média acima de 4?

# %%
df1[df1["aggregate_rating"] > 4]["city"].value_counts().idxmax()
# Out:
# 'Bangalore'

# %% [markdown]
# ## 3. Qual o nome da cidade que possui mais restaurantes com nota média abaixo de 2.5?

# %%
df1[df1["aggregate_rating"] < 2.5]["city"].value_counts().idxmax()
# Out:
# 'Gangtok'

# %% [markdown]
# ## 4. Qual o nome da cidade que possui o maior valor médio de um prato para dois?

# %%
df1.groupby("city")["average_cost_for_two"].nunique().idxmax()
# Out:
# 'Dubai'

# %% [markdown]
# ## 5. Qual o nome da cidade que possui a maior quantidade de tipos de culinária distintas?

# %%
df1.groupby("city")["cuisines"].nunique().idxmax()
# Out:
# 'Birmingham'

# %% [markdown]
# ## 6. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem reservas?

# %%
df1.groupby("city")["has_table_booking"].nunique().idxmax()
# Out:
# 'Abu Dhabi'

# %% [markdown]
# ## 7. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem entregas?

# %%
df1.groupby("city")["is_delivering_now"].nunique().idxmax()
# Out:
# 'Abu Dhabi'

# %% [markdown]
# ## 8. Qual o nome da cidade que possui a maior quantidade de restaurantes que aceitam pedidos online?

# %%
df1.groupby("city")["has_online_delivery"].nunique().reset_index()
# Out:
#                 city  has_online_delivery
# 0          Abu Dhabi                    2
# 1           Adelaide                    1
# 2               Agra                    2
# 3          Ahmedabad                    2
# 4          Allahabad                    2
# ..               ...                  ...
# 120    Washington DC                    1
# 121       Wellington                    1
# 122  Wellington City                    1
# 123         Zirakpur                    1
# 124         İstanbul                    1
#
# [125 rows x 2 columns]

# %% [markdown]
# # Restaurantes

# %% [markdown]
# ## 1. Qual o nome do restaurante que possui a maior quantidade de avaliações?

# %%
df1.groupby("restaurant_name")["votes"].nunique().idxmax()
# Out:
# "Domino's Pizza"

# %% [markdown]
# ## 2. Qual o nome do restaurante com a maior nota média?

# %%
df1.groupby("restaurant_name")["aggregate_rating"].mean().idxmax()
# Out:
# '5 Napkin Burger'

# %% [markdown]
# ## 3. Qual o nome do restaurante que possui o maior valor de um prato para duas pessoas?

# %%
df1.groupby("restaurant_name")["average_cost_for_two"].nunique().idxmax()
# Out:
# 'The Chocolate Room'

# %% [markdown]
# ## 4. Qual o nome do restaurante de tipo de culinária brasileira que possui a menor média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Brazilian")].groupby("restaurant_name")["aggregate_rating"].mean().idxmin()
# Out:
# 'Bar do Luiz Fernandes'

# %% [markdown]
# ## 5. Qual o nome do restaurante de tipo de culinária brasileira, e que é do Brasil, que possui a maior média de avaliação?

# %%
df1[(df1["cuisines"].str.contains("Brazilian")) & (df1["country"] == "Brazil")].nlargest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Braseiro da Gávea'

# %% [markdown]
# ## 6. Os restaurantes que aceitam pedido online são também, na média, os restaurantes que mais possuem avaliações registradas?

# %%
df1.groupby("has_online_delivery")["votes"].mean()[1] > df1.groupby("has_online_delivery")["votes"].mean()[0]
# Out:
# True

# %% [markdown]
# ## 7. Os restaurantes que fazem reservas são também, na média, os restaurantes que possuem o maior valor médio de um prato para duas pessoas?

# %%
df1.groupby("has_table_booking")["average_cost_for_two"].mean()[1] > df1.groupby("has_table_booking")["average_cost_for_two"].mean()[0]
# Out:
# True

# %% [markdown]
# ## 8. Os restaurantes do tipo de culinária japonesa dos Estados Unidos da América possuem um valor médio de prato para duas pessoas maior que as churrascarias americanas (BBQ)?

# %%
df1[df1["cuisines"].str.contains("Japanese") & (df1["country"] == "United States of America")]["average_cost_for_two"].mean() > df1[df1["cuisines"].str.contains("BBQ") & (df1["country"] == "United States of America")]["average_cost_for_two"].mean()
# Out:
# False

# %% [markdown]
# # Tipos de Culinária

# %% [markdown]
# ## 1. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a maior média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Italian")].nlargest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# "Andre's Cucina & Polenta Bar"

# %% [markdown]
# ## 2. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a menor média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Italian")].nsmallest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Avenida Paulista'

# %% [markdown]
# ## 3. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a maior média de avaliação?

# %%
df1[df1["cuisines"].str.contains("American")].nlargest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Brick Store Pub'

# %% [markdown]
# ## 4. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a menor média de avaliação?

# %%
df1[df1["cuisines"].str.contains("American")].nsmallest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Alston Bar & Beef'

# %% [markdown]
# ## 5. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a maior média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Arabian")].nlargest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Mandi@36'

# %% [markdown]
# ## 6. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a menor média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Arabian")].nsmallest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Raful'

# %% [markdown]
# ## 7. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a maior média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Japanese")].nlargest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Mendokoro Ramenba'

# %% [markdown]
# ## 8. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a menor média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Japanese")].nsmallest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Banzai Sushi'

# %% [markdown]
# ## 9. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a maior média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Home-made")].nlargest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'Kanaat Lokantası'

# %% [markdown]
# ## 10. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a menor média de avaliação?

# %%
df1[df1["cuisines"].str.contains("Home-made")].nsmallest(1, "aggregate_rating")["restaurant_name"].values[0]
# Out:
# 'GurMekan Restaurant'

# %% [markdown]
# ## 11. Qual o tipo de culinária que possui o maior valor médio de um prato para duas pessoas?

# %%
df1.groupby("cuisines")["average_cost_for_two"].mean().idxmax()
# Out:
# 'Modern Australian'

# %% [markdown]
# ## 12. Qual o tipo de culinária que possui a maior nota média?

# %%
df1.groupby("cuisines")["aggregate_rating"].mean().idxmax()
# Out:
# 'Others'

# %% [markdown]
# ## 13. Qual o tipo de culinária que possui mais restaurantes que aceitam pedidos online e fazem entregas?

# %%
df1[(df1["has_online_delivery"] == True) & (df1["is_delivering_now"] == True)]["cuisines"].mode().iloc[0]
# Out:
# 'North Indian'
